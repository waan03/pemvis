# %% [markdown]
# # Realisasi Lingkaran

# %%
print("\033c")
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-8,8,10000)
plt.figure(figsize=(8,6.5))

y= x-x-0
y1 = (4-x**2)**0.5
y2 = -(4-x**2)**0.5


y3 = 5 + (4-(x-5)**2)**0.5
y4 = 5 - (4-(x-5)**2)**0.5

y5 = -5 + (4-(x-5)**2)**0.5
y6 = -5 - (4-(x-5)**2)**0.5

y7 = 5 + (4-(x+5)**2)**0.5
y8 = 5 - (4-(x+5)**2)**0.5

y9  = -5 + (4-(x+5)**2)**0.5
y10 = -5 - (4-(x+5)**2)**0.5


plt.plot(x,y, '-k')

plt.plot(x,y1, '-r', label='y1, y2')
plt.plot(x,y2, '-r')
plt.plot(x,y3, '-g', label='y3, y4')
plt.plot(x,y4, '-g')
plt.plot(x,y5, '-b', label='y5, y6')
plt.plot(x,y6, '-b')
plt.plot(x,y7, 'y', label='y7, y8')
plt.plot(x,y8, 'y')
plt.plot(x,y9, '-y', label='y9, y10')
plt.plot(x,y10, '-y')

plt.legend(loc='upper center')
plt.grid()
plt.show()
# Out:
# c
# <ipython-input-6-0591623ee4bb>:9: RuntimeWarning: invalid value encountered in sqrt
#   y1 = (4-x**2)**0.5
# <ipython-input-6-0591623ee4bb>:10: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -(4-x**2)**0.5
# <ipython-input-6-0591623ee4bb>:13: RuntimeWarning: invalid value encountered in sqrt
#   y3 = 5 + (4-(x-5)**2)**0.5
# <ipython-input-6-0591623ee4bb>:14: RuntimeWarning: invalid value encountered in sqrt
#   y4 = 5 - (4-(x-5)**2)**0.5
# <ipython-input-6-0591623ee4bb>:16: RuntimeWarning: invalid value encountered in sqrt
#   y5 = -5 + (4-(x-5)**2)**0.5
# <ipython-input-6-0591623ee4bb>:17: RuntimeWarning: invalid value encountered in sqrt
#   y6 = -5 - (4-(x-5)**2)**0.5
# <ipython-input-6-0591623ee4bb>:19: RuntimeWarning: invalid value encountered in sqrt
#   y7 = 5 + (4-(x+5)**2)**0.5
# <ipython-input-6-0591623ee4bb>:20: RuntimeWarning: invalid value encountered in sqrt
#   y8 = 5 - (4-(x+5)**2)**0.5
# <ipython-input-6-0591623ee4bb>:22: RuntimeWarning: invalid value encountered in sqrt
#   y9  = -5 + (4-(x+5)**2)**0.5
# <ipython-input-6-0591623ee4bb>:23: RuntimeWarning: invalid value encountered in sqrt
#   y10 = -5 - (4-(x+5)**2)**0.5

# %% [markdown]
# Latihan (Buat Mickey Mouse)

# %%
print("\033c")
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-20,20,10000)
plt.figure(figsize=(8,8))

y= x-x-0
y3 = 5 + (25-(x-5)**2)**0.5
y4 = 5 - (25-(x-5)**2)**0.5

plt.plot(x,y3, '-k')
plt.plot(x,y4, '-k')

def telinga(t1,t2):
  y= x-x-0
  y1 = t1 + (4-(x-t2)**2)**0.5
  y2 = t1 - (4-(x-t2)**2)**0.5
  plt.plot(x,y1, '-k')
  plt.plot(x,y2, '-k')

# for i in range(a,b):


telinga(10,1)
telinga(10,9)

plt.legend(loc='upper center')

plt.show
# Out:
# <ipython-input-26-19a56261163b>:9: RuntimeWarning: invalid value encountered in sqrt
#   y3 = 5 + (25-(x-5)**2)**0.5
# <ipython-input-26-19a56261163b>:10: RuntimeWarning: invalid value encountered in sqrt
#   y4 = 5 - (25-(x-5)**2)**0.5
# <ipython-input-26-19a56261163b>:17: RuntimeWarning: invalid value encountered in sqrt
#   y1 = t1 + (4-(x-t2)**2)**0.5
# <ipython-input-26-19a56261163b>:18: RuntimeWarning: invalid value encountered in sqrt
#   y2 = t1 - (4-(x-t2)**2)**0.5
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Realisasi Kurva Parabolik

# %%
print("\033c")
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-4,4,10000)
plt.figure(figsize=(3,30))

plt.plot(x, (0.01-x**2)**0.5, '-k')
plt.plot(x, -((0.01-x**2)**0.5), '-k')

y = x-x-0
y1 = x**3 - 2*x**2 - 5*x + 6
plt.plot(x,y,'-k')
plt.plot(x,y1, '-r', label='y1')

plt.legend(loc='lower center')
plt.grid()
plt.show()
# Out:
# c
# <ipython-input-8-c835f6c9c666>:8: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, (0.01-x**2)**0.5, '-k')
# <ipython-input-8-c835f6c9c666>:9: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, -((0.01-x**2)**0.5), '-k')

# %%
print("\033c")
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-3,3,10000)
plt.figure(figsize=(3,10))

plt.plot(x, (0.01-x**2)**0.5, '-k')
plt.plot(x, -((0.01-x**2)**0.5), '-k')

y = x-x-0
y1 = -(x**3 - 2*x**2 - x + 2)
plt.plot(x,y,'-k')
plt.plot(x,y1, '-r', label='y1')

plt.legend(loc='lower center')
plt.grid()
plt.show()
# Out:
# c
# <ipython-input-3-53f8cccecb19>:8: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, (0.01-x**2)**0.5, '-k')
# <ipython-input-3-53f8cccecb19>:9: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, -((0.01-x**2)**0.5), '-k')

# %% [markdown]
# ### **Pertemuan 5**
